# %% [markdown]
# <h1 align=center><font size = 5>Battle of Neighborhood in Atlanta</font></h1>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Download and Explore Dataset</a>
#
# 2. <a href="#item2">Explore Neighborhoods in Atlanta</a>
#
# 3. <a href="#item3">Cluster Neighborhoods</a>
#
# 4. <a href="#item4">Examine Clusters</a>
#
# </font>
# </div>

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2p-h14c3975_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## 1. Download and Explore Dataset

# %%
import requests
import pandas as pd
from geopy.geocoders import Nominatim
import folium
import numpy as np 
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %% [markdown]
# load the neighborhood data by using read_html function in pandas

# %%
url = 'https://en.wikipedia.org/wiki/Table_of_Atlanta_neighborhoods_by_population'

# %%
df=pd.read_html(url,attrs = {'class': 'wikitable sortable'}, header=0)
df=pd.DataFrame(df[0])
df['Neighborhood']=df['Neighborhood'].astype(str)+', Atlanta'
address = df['Neighborhood'].values.tolist()

# %%
column_names = ['Neighborhood', 'Latitude', 'Longitude'] 

df_Atlanta = pd.DataFrame(columns=column_names)

# %% [markdown]
# Use geopy library to get the latitude and longitude values of Neighborhoods in Atlanta.

# %%
geolocator = Nominatim(user_agent="capstoneproject")
for i in address: 
    location = geolocator.geocode(i)
    
    if location is None: 
        location = geolocator.geocode("{},Atlanta, GA".format(i))
    if location is None: 
        print("The location data of {} is not available!".format(i))
    else:
        latitude = location.latitude
        longitude = location.longitude
        
        df_Atlanta = df_Atlanta.append({'Neighborhood': i,
                                          'Latitude': latitude,
                                          'Longitude': longitude}, ignore_index=True)
# Out:
# The location data of Almond Park, Atlanta is not available!
# The location data of Arlington Estates, Atlanta is not available!
# The location data of Baker Hills, Atlanta is not available!
# The location data of Betmar LaVilla, Atlanta is not available!
# The location data of Capitol Gateway, Atlanta is not available!
# The location data of Carver Hills, Atlanta is not available!
# The location data of Cascade Avenue/Road, Atlanta is not available!
# The location data of Chosewood Park, Atlanta is not available!
# The location data of Custer/McDonough/Guice, Atlanta is not available!
# The location data of Druid Hills (City of Atlanta), Atlanta is not available!
# The location data of East Chastain Park, Atlanta is not available!
# The location data of Fairburn Mays, Atlanta is not available!
# The location data of Fairway Acres, Atlanta is not available!
# The location data of Glenrose Heights, Atlanta is not available!
# The location data of Harland Terrace, Atlanta is not available!
# The location data of Harris Chiles, Atlanta is not available!
# The location data of Knight Park/Howell Station, Atlanta is not available!
# The location data of Lindridge/Martin Manor, Atlanta is not available!
# The location data of Marietta Street Artery, Atlanta is not available!
# The location data of Midwest Cascade, Atlanta is not available!
# The location data of Monroe Heights, Atlanta is not available!
# The location data of Mt. Paran/Northside, Atlanta is not available!
# The location data of Old Fourth Ward, Atlanta is not available!
# The location data of Peachtree Battle Alliance, Atlanta is not available!
# The location data of Penelope Neighbors, Atlanta is not available!
# The location data of Pamond Park, Atlanta is not available!
# The location data of Poncey-Highland, Atlanta is not available!
# The location data of Scotts Crossing, Atlanta is not available!
# The location data of South Tuxedo Park, Atlanta is not available!
# The location data of Swallow Circle/Baywood, Atlanta is not available!
# The location data of The Villages at Carver, Atlanta is not available!
# The location data of The Villages at Castleberry Hill, Atlanta is not available!
# The location data of The Villages at East Lake, Atlanta is not available!
# The location data of West Paces Ferry/Northside, Atlanta is not available!
# The location data of Wilson Mill Meadows, Atlanta is not available!

# %%
df_Atlanta.head()
# Out:
#            Neighborhood   Latitude  Longitude
# 0   Adair Park, Atlanta  33.724974 -84.411429
# 1   Adams Park, Atlanta  33.712052 -84.456873
# 2   Adamsville, Atlanta  33.759274 -84.505209
# 3  Ansley Park, Atlanta  33.794550 -84.376315
# 4      Ardmore, Atlanta  33.806282 -84.400028

# %%
address = 'Atlanta, GA'
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Atlanta are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Atlanta are 33.7490987, -84.3901849.

# %% [markdown]
# Create a map of Atlanta with neighborhoods superimposed on top.

# %%
map_Atlanta = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(df_Atlanta['Latitude'], df_Atlanta['Longitude'], df_Atlanta['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Atlanta)  
    
map_Atlanta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# @hidden_cell
CLIENT_ID = 'G2T5UW3LY2XD3V5PCGF52ORGOCGZJ0BE3MVFE1EQ0DQMWGBL' # your Foursquare ID
CLIENT_SECRET = 'EWPYHMFSIMPBLESGBY05RVHZU55BUXV5UMMRMFXEKTSHH45K' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ## 2. Explore Neighborhoods in Atlanta

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=15000, limit=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Atlanta_venues = getNearbyVenues(names=df_Atlanta['Neighborhood'],
                                   latitudes=df_Atlanta['Latitude'],
                                   longitudes=df_Atlanta['Longitude']
                                  )
# Out:
# Adair Park, Atlanta
# Adams Park, Atlanta
# Adamsville, Atlanta
# Ansley Park, Atlanta
# Ardmore, Atlanta
# Argonne Forest, Atlanta
# Adair Park, Atlanta
# Adams Park, Atlanta
# Adamsville, Atlanta
# Ansley Park, Atlanta
# Ardmore, Atlanta
# Argonne Forest, Atlanta
# Ashview Heights, Atlanta
# Atlanta University Center, Atlanta
# Atlantic Station, Atlanta
# Audubon Forest, Atlanta
# Bankhead, Atlanta
# Beecher Hills, Atlanta
# Ben Hill, Atlanta
# Ben Hill Terrace, Atlanta
# Benteen Park, Atlanta
# Berkeley Park, Atlanta
# Bolton, Atlanta
# Boulevard Heights, Atlanta
# Brandon, Atlanta
# Brookhaven (City of Atlanta), Atlanta
# Brookwood, Atlanta
# Brookwood Hills, Atlanta
# Browns Mill Park, Atlanta
# Buckhead Forest, Atlanta
# Buckhead Village, Atlanta
# Cabbagetown, Atlanta
# Campbellton Road, Atlanta
# Candler Park, Atlanta
# Capitol View, Atlanta
# Capitol View Manor, Atlanta
# Carey Park, Atlanta
# Carroll Heights, Atlanta
# Cascade Heights, Atlanta
# Castleberry Hill, Atlanta
# Castlewood, Atlanta
# Center Hill, Atlanta
# Chastain Park, Atlanta
# Collier Heights, Atlanta
# Collier Hills, Atlanta
# Cross Creek, Atlanta
# Deerwood, Atlanta
# Dixie Hills, Atlanta
# Downtown, Atlanta
# East Atlanta, Atlanta
# East Lake, Atlanta
# Edgewood, Atlanta
# English Avenue, Atlanta
# Fairburn Heights, Atlanta
# Florida Heights, Atlanta
# Fort McPherson, Atlanta
# Garden Hills, Atlanta
# Georgia Tech, Atlanta
# Grant Park, Atlanta
# Greenbriar, Atlanta
# Grove Park, Atlanta
# Hammond Park, Atlanta
# Heritage Valley, Atlanta
# Hills Park, Atlanta
# Home Park, Atlanta
# Hunter Hills, Atlanta
# Inman Park, Atlanta
# Joyland, Atlanta
# Kings Forest, Atlanta
# Kingswood, Atlanta
# Kirkwood, Atlanta
# Lake Claire, Atlanta
# Lakewood, Atlanta
# Lakewood Heights, Atlanta
# Leila Valley, Atlanta
# Lenox, Atlanta
# Lincoln Homes, Atlanta
# Lindbergh, Atlanta
# Loring Heights, Atlanta
# Margaret Mitchell, Atlanta
# Mays, Atlanta
# Mechanicsville, Atlanta
# Midtown, Atlanta
# Morningside/Lenox Park, Atlanta
# Mozley Park, Atlanta
# North Buckhead, Atlanta
# Norwood Manor, Atlanta
# Oakland City, Atlanta
# Old Gordon, Atlanta
# Orchard Knob, Atlanta
# Ormewood Park, Atlanta
# Paces, Atlanta
# Peachtree Heights East, Atlanta
# Peachtree Heights West, Atlanta
# Peachtree Hills, Atlanta
# Peachtree Park, Atlanta
# Peoplestown, Atlanta
# Perkerson, Atlanta
# Peyton Forest, Atlanta
# Piedmont Heights, Atlanta
# Pine Hills, Atlanta
# Pittsburgh, Atlanta
# Polar Rock, Atlanta
# Princeton Lakes, Atlanta
# Reynoldstown, Atlanta
# Ridgedale Park, Atlanta
# Ridgewood Heights, Atlanta
# Riverside, Atlanta
# Rockdale, Atlanta
# Rosedale Heights, Atlanta
# South Atlanta, Atlanta
# South River Gardens, Atlanta
# Southwest, Atlanta
# Springlake, Atlanta
# Summerhill, Atlanta
# Sweet Auburn, Atlanta
# Sylvan Hills, Atlanta
# Thomasville Heights, Atlanta
# Tuxedo Park, Atlanta
# Underwood Hills, Atlanta
# Venetian Hills, Atlanta
# Vine City, Atlanta
# Virginia-Highland, Atlanta
# Washington Park, Atlanta
# West End, Atlanta
# West Highlands, Atlanta
# West Lake, Atlanta
# Westview, Atlanta
# Westwood Terrace, Atlanta
# Whittier Mill Village, Atlanta
# Wildwood, Atlanta
# Wisteria Gardens, Atlanta

# %% [markdown]
# Let's check the size of the resulting dataframe

# %%
Atlanta_venues=Atlanta_venues[Atlanta_venues['Venue Category'].str.contains("Restaurant")]
print(Atlanta_venues.shape)
Atlanta_venues.head()
# Out:
# (3270, 7)
#            Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 11  Adair Park, Atlanta              33.724974              -84.411429
# 14  Adair Park, Atlanta              33.724974              -84.411429
# 20  Adair Park, Atlanta              33.724974              -84.411429
# 24  Adair Park, Atlanta              33.724974              -84.411429
# 29  Adair Park, Atlanta              33.724974              -84.411429
#
#                               Venue  Venue Latitude  Venue Longitude  \
# 11                Nick's Food To Go       33.747492       -84.379749
# 14                  Aviva by Kameel       33.760597       -84.386548
# 20  Six Feet Under Pub & Fish House       33.746555       -84.372869
# 24                      Alma Cocina       33.759070       -84.387536
# 29                            Agave       33.747968       -84.368020
#
#                Venue Category
# 11           Greek Restaurant
# 14   Mediterranean Restaurant
# 20         Seafood Restaurant
# 24  Latin American Restaurant
# 29         Mexican Restaurant

# %% [markdown]
# Group and count the restaurant by type in each neighborhood

# %%
Atlanta_onehot = pd.get_dummies(Atlanta_venues[['Venue Category']], prefix="", prefix_sep="")

Atlanta_onehot['Neighborhood'] = Atlanta_venues['Neighborhood']

fixed_columns = [Atlanta_onehot.columns[-1]] + list(Atlanta_onehot.columns[:-1])
Atlanta_onehot = Atlanta_onehot[fixed_columns]

Atlanta_onehot.head()
# Out:
#            Neighborhood  African Restaurant  American Restaurant  \
# 11  Adair Park, Atlanta                   0                    0
# 14  Adair Park, Atlanta                   0                    0
# 20  Adair Park, Atlanta                   0                    0
# 24  Adair Park, Atlanta                   0                    0
# 29  Adair Park, Atlanta                   0                    0
#
#     Arepa Restaurant  Asian Restaurant  Brazilian Restaurant  \
# 11                 0                 0                     0
# 14                 0                 0                     0
# 20                 0                 0                     0
# 24                 0                 0                     0
# 29                 0                 0                     0
#
#     Cajun / Creole Restaurant  Caribbean Restaurant  Chinese Restaurant  \
# 11                          0                     0                   0
# 14                          0                     0                   0
# 20                          0                     0                   0
# 24                          0                     0                   0
# 29                          0                     0                   0
#
#     Comfort Food Restaurant          ...            Restaurant  \
# 11                        0          ...                     0
# 14                        0          ...                     0
# 20                        0          ...                     0
# 24                        0          ...                     0
# 29                        0          ...                     0
#
#     Seafood Restaurant  South Indian Restaurant  \
# 11                   0                        0
# 14                   0                        0
# 20                   1                        0
# 24                   0                        0
# 29                   0                        0
#
#     Southern / Soul Food Restaurant  Spanish Restaurant  Sushi Restaurant  \
# 11                                0                   0                 0
# 14                                0                   0                 0
# 20                                0                   0                 0
# 24                                0                   0                 0
# 29                                0                   0                 0
#
#     Tapas Restaurant  Thai Restaurant  Vegetarian / Vegan Restaurant  \
# 11                 0                0                              0
# 14                 0                0                              0
# 20                 0                0                              0
# 24                 0                0                              0
# 29                 0                0                              0
#
#     Vietnamese Restaurant
# 11                      0
# 14                      0
# 20                      0
# 24                      0
# 29                      0
#
# [5 rows x 38 columns]

# %% [markdown]
# Count the total restaurants in each neighborhood

# %%
df=Atlanta_venues[['Neighborhood','Venue Category']].groupby('Neighborhood').count()
df.sort_values(by='Venue Category',ascending=False).head()
# Out:
#                       Venue Category
# Neighborhood
# Adamsville, Atlanta               60
# Adams Park, Atlanta               58
# Adair Park, Atlanta               52
# Ardmore, Atlanta                  46
# Ansley Park, Atlanta              44

# %% [markdown]
# Add the total restaurant count into the dataframe

# %%
Atlanta_grouped = Atlanta_onehot.groupby('Neighborhood').sum().reset_index()
Atlanta_grouped.head()
# Out:
#            Neighborhood  African Restaurant  American Restaurant  \
# 0   Adair Park, Atlanta                   0                    8
# 1   Adams Park, Atlanta                   0                    4
# 2   Adamsville, Atlanta                   0                    6
# 3  Ansley Park, Atlanta                   0                    8
# 4      Ardmore, Atlanta                   0                    4
#
#    Arepa Restaurant  Asian Restaurant  Brazilian Restaurant  \
# 0                 0                 0                     0
# 1                 0                 2                     0
# 2                 0                 2                     0
# 3                 0                 0                     0
# 4                 0                 0                     2
#
#    Cajun / Creole Restaurant  Caribbean Restaurant  Chinese Restaurant  \
# 0                          0                     0                   0
# 1                          0                     0                   0
# 2                          0                     0                   0
# 3                          0                     0                   0
# 4                          0                     0                   0
#
#    Comfort Food Restaurant          ...            Restaurant  \
# 0                        0          ...                     4
# 1                        0          ...                     4
# 2                        0          ...                     0
# 3                        0          ...                     2
# 4                        0          ...                     2
#
#    Seafood Restaurant  South Indian Restaurant  \
# 0                   4                        0
# 1                   4                        0
# 2                   6                        0
# 3                   4                        0
# 4                   4                        0
#
#    Southern / Soul Food Restaurant  Spanish Restaurant  Sushi Restaurant  \
# 0                                4                   0                 0
# 1                                2                   0                 2
# 2                                8                   0                 0
# 3                                6                   0                 0
# 4                                6                   0                 2
#
#    Tapas Restaurant  Thai Restaurant  Vegetarian / Vegan Restaurant  \
# 0                 2                2                              2
# 1                 2                2                              2
# 2                 2                4                              4
# 3                 2                6                              0
# 4                 2                6                              0
#
#    Vietnamese Restaurant
# 0                      2
# 1                      2
# 2                      2
# 3                      0
# 4                      0
#
# [5 rows x 38 columns]

# %% [markdown]
# list the top 5 most popular restaurant

# %%
df1=Atlanta_venues[['Venue','Venue Category']]
df1=df1.drop_duplicates()
df2=df1.groupby('Venue Category').count().sort_values(by='Venue',ascending=False)
df2.head()
# Out:
#                        Venue
# Venue Category
# American Restaurant       36
# Mexican Restaurant        29
# Italian Restaurant        18
# Seafood Restaurant        14
# Vietnamese Restaurant     13

# %%
df3=pd.DataFrame(columns=['Neighborhood','American Restaurant','Total'])
df3[['Neighborhood','American Restaurant']]=Atlanta_grouped[['Neighborhood','American Restaurant']]
df3['Total']=Atlanta_grouped.sum(axis=1)
df3.head()
# Out:
#            Neighborhood  American Restaurant  Total
# 0   Adair Park, Atlanta                    8     52
# 1   Adams Park, Atlanta                    4     58
# 2   Adamsville, Atlanta                    6     60
# 3  Ansley Park, Atlanta                    8     44
# 4      Ardmore, Atlanta                    4     46

# %% [markdown]
# ## 3. Clustering Neighborhood

# %%
# set number of clusters
kclusters = 8

Atlanta_grouped_clustering = df3.drop('Neighborhood', 1)
normalized_Atlanta_grouped_clustering = preprocessing.normalize(Atlanta_grouped_clustering)

#Atlanta_grouped_clustering
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(normalized_Atlanta_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 5, 1, 2, 5, 6, 2, 1, 4, 5], dtype=int32)

# %%
df3['Cluster Lables']=kmeans.labels_

# %%
Atlanta_merged = df_Atlanta

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Atlanta_merged = Atlanta_merged.join(df3.set_index('Neighborhood'), on='Neighborhood')

Atlanta_merged.head() # check the last columns!
# Out:
#            Neighborhood   Latitude  Longitude  American Restaurant  Total  \
# 0   Adair Park, Atlanta  33.724974 -84.411429                    8     52
# 1   Adams Park, Atlanta  33.712052 -84.456873                    4     58
# 2   Adamsville, Atlanta  33.759274 -84.505209                    6     60
# 3  Ansley Park, Atlanta  33.794550 -84.376315                    8     44
# 4      Ardmore, Atlanta  33.806282 -84.400028                    4     46
#
#    Cluster Lables
# 0               4
# 1               5
# 2               1
# 3               2
# 4               5

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Atlanta_merged['Latitude'], Atlanta_merged['Longitude'], Atlanta_merged['Neighborhood'], Atlanta_merged['Cluster Lables']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Exam Clusters

# %%
Atlanta_merged.loc[Atlanta_merged['Cluster Lables'] == 7, Atlanta_merged.columns[[0,3,4] + list(range(5, Atlanta_merged.shape[1]))]]
# Out:
#                         Neighborhood  American Restaurant  Total  \
# 18                 Ben Hill, Atlanta                    1     30
# 19         Ben Hill Terrace, Atlanta                    1     30
# 45              Cross Creek, Atlanta                    1     22
# 91                    Paces, Atlanta                    1     24
# 92   Peachtree Heights East, Atlanta                    1     23
# 93   Peachtree Heights West, Atlanta                    1     23
# 118             Tuxedo Park, Atlanta                    1     26
# 119         Underwood Hills, Atlanta                    1     22
#
#      Cluster Lables
# 18                7
# 19                7
# 45                7
# 91                7
# 92                7
# 93                7
# 118               7
# 119               7
